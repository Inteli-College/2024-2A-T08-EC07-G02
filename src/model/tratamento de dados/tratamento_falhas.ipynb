# %% [markdown]
# # 1. Exploração e limpeza das bases de dados

# %%
# importacao das dependencias
import pandas as pd
import numpy as np

# %% [markdown]
# ## Converte **_xlsx_** para **_csv_**

# %%
# Ler a planilha
df = pd.read_excel('../tabelas originais/FALHAS')

# Converter para .csv
csv_file = '..tabelas originais/FALHAS.csv'
df.to_csv(csv_file, index=False)

# %% [markdown]
# ## Base de dados "FALHAS"

# %%
# Leitura da base de dados falhas
df_falhas = pd.read_csv('../FALHAS.csv')
df_falhas
# Out:
#                  KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 0       2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521   ZP5
# 1       2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521   ZP5
# 2       2023-4130482  AUDI Q3  2Y2Y   DSN  PCEQS999  2054701  ESPC
# 3       2023-4130482  AUDI Q3  2Y2Y   DSN  PCEQS999  2054701  ESPC
# 4       2023-4130664  AUDI Q3  6Y6Y   DSN  PCEQS805  7000240  ZP82
# ...              ...      ...   ...   ...       ...      ...   ...
# 992715  2024-2556363  T-CROSS  6UA1   CWL      SMT2  FHQWRAP  ZP8
# 992716  2024-2556363  T-CROSS  6UA1   CWL      SMT2  FHQWRAP  ZP8
# 992717  2024-2546444  T-CROSS  2R2R   DHS      SMT2  FHQWRAP  ZP8
# 992718  2024-2546444  T-CROSS  2R2R   DHS      SMT2  FHQWRAP  ZP8
# 992719  2024-2546444  T-CROSS  2R2R   DHS      SMT2  FHQWRAP  ZP8
#
#                                                 FALHA                 DATA
# 0                      Porta dianteira Folga (Ajuste)  09-01-2023 22:24:44
# 1                       Porta traseira Folga (Ajuste)  09-01-2023 22:25:02
# 2                        Lanterna tras (09) Interfere  10-01-2023 09:18:25
# 3       Emblema / logo - Adesivos em geral Solto(a) ¨  10-01-2023 09:18:40
# 4                       Painel instrumentos Ruído (-)  10-01-2023 11:17:56
# ...                                               ...                  ...
# 992715                    FAROL (09) PEÇA INCORRETA ¨  25-06-2024 13:09:25
# 992716                      SMART INSPECTION PEÇA NOK  25-06-2024 13:09:25
# 992717                      SMART INSPECTION PEÇA NOK  25-06-2024 13:10:35
# 992718         FAROL DE NEBLINA (09) PEÇA INCORRETA ¨  25-06-2024 13:10:35
# 992719                    FAROL (09) PEÇA INCORRETA ¨  25-06-2024 13:10:35
#
# [992720 rows x 9 columns]

# %%
# Visualização da forma da base de dados para saber com que estamos lidando
df_falhas.shape
# Out:
# (992720, 9)

# %%
# Para saber que os dados que estão dispostos para trabalharmos
df_falhas.columns
# Out:
# Index(['KNR', 'MODELO', 'COR', 'MOTOR', 'ESTACAO', 'USUARIO', 'HALLE', 'FALHA',
#        'DATA'],
#       dtype='object')

# %%
# Saber os tipos de cada coluna para ter noção do que vamos lidar 
df_falhas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992720 entries, 0 to 992719
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   KNR      992720 non-null  object
#  1   MODELO   992720 non-null  object
#  2   COR      992720 non-null  object
#  3   MOTOR    992720 non-null  object
#  4   ESTACAO  992707 non-null  object
#  5   USUARIO  992707 non-null  object
#  6   HALLE    990868 non-null  object
#  7   FALHA    992710 non-null  object
#  8   DATA     992720 non-null  object
# dtypes: object(9)
# memory usage: 68.2+ MB

# %%
# Ter informações de quais dados são nulos e sua quantidade para saber quatos irão ser descartados
df_falhas.isna().sum()
# Out:
# KNR           0
# MODELO        0
# COR           0
# MOTOR         0
# ESTACAO      13
# USUARIO      13
# HALLE      1852
# FALHA        10
# DATA          0
# dtype: int64

# %%
# Visualizar quais modelos estão dispostos na base de dados 
df_falhas['MODELO'].value_counts()
# Out:
# MODELO
# T-CROSS       986064
# T-CROSS PA      3439
# AUDI Q3         3217
# Name: count, dtype: int64

# %%
# Limpar a base de dados para excluir todos os campos que estão vazios
df_falhas_limpa = df_falhas.dropna()
df_falhas_limpa.shape
# Out:
# (990858, 9)

# %%
# Ter mais informações sobre como os dados estão organizados em seus tipos
df_falhas_limpa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 990858 entries, 0 to 992719
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   KNR      990858 non-null  object
#  1   MODELO   990858 non-null  object
#  2   COR      990858 non-null  object
#  3   MOTOR    990858 non-null  object
#  4   ESTACAO  990858 non-null  object
#  5   USUARIO  990858 non-null  object
#  6   HALLE    990858 non-null  object
#  7   FALHA    990858 non-null  object
#  8   DATA     990858 non-null  object
# dtypes: object(9)
# memory usage: 75.6+ MB

# %%
# Pegar somente os dados do tipo T-Cross, pois será o foco da analise
df_falhas_limpa1 = df_falhas_limpa[df_falhas_limpa['MODELO'] == 'T-CROSS']
df_falhas_limpa1
# Out:
#                  KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 0       2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521   ZP5
# 1       2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521   ZP5
# 17      2023-0616455  T-CROSS  0Q0Q   CWS  PCEQS100  4004672   ZP5
# 18      2023-0616455  T-CROSS  0Q0Q   CWS  PCEQS100  4004672   ZP5
# 20      2023-0616455  T-CROSS  0Q0Q   CWS  PCEQS102  4005127   ZP5
# ...              ...      ...   ...   ...       ...      ...   ...
# 992715  2024-2556363  T-CROSS  6UA1   CWL      SMT2  FHQWRAP  ZP8
# 992716  2024-2556363  T-CROSS  6UA1   CWL      SMT2  FHQWRAP  ZP8
# 992717  2024-2546444  T-CROSS  2R2R   DHS      SMT2  FHQWRAP  ZP8
# 992718  2024-2546444  T-CROSS  2R2R   DHS      SMT2  FHQWRAP  ZP8
# 992719  2024-2546444  T-CROSS  2R2R   DHS      SMT2  FHQWRAP  ZP8
#
#                                          FALHA                 DATA
# 0               Porta dianteira Folga (Ajuste)  09-01-2023 22:24:44
# 1                Porta traseira Folga (Ajuste)  09-01-2023 22:25:02
# 17            Painel lateral 04. Caroço / Pico  12-01-2023 10:09:25
# 18                 Painel lateral 01. Amassado  12-01-2023 10:09:33
# 20                 Painel lateral 01. Amassado  12-01-2023 11:52:21
# ...                                        ...                  ...
# 992715             FAROL (09) PEÇA INCORRETA ¨  25-06-2024 13:09:25
# 992716               SMART INSPECTION PEÇA NOK  25-06-2024 13:09:25
# 992717               SMART INSPECTION PEÇA NOK  25-06-2024 13:10:35
# 992718  FAROL DE NEBLINA (09) PEÇA INCORRETA ¨  25-06-2024 13:10:35
# 992719             FAROL (09) PEÇA INCORRETA ¨  25-06-2024 13:10:35
#
# [984284 rows x 9 columns]

# %%
# Pegar somente os dados do tipo ROD, pois será o foco da analise
df_falhas_limpa = df_falhas_limpa1[df_falhas_limpa1['HALLE'] == 'ROD']

df_falhas_limpa
# Out:
#                  KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  T-CROSS  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  T-CROSS  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  T-CROSS  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  T-CROSS  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  T-CROSS  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...      ...   ...   ...       ...      ...   ...
# 977650  2024-2526472  T-CROSS  2R2R   DHS  PCEQS709  2034913   ROD
# 977750  2024-2446009  T-CROSS  0QA1   DHS  PCEQS709  4013395   ROD
# 979175  2024-2526492  T-CROSS  K2K2   DHS  PCEQS709  4024346   ROD
# 979317  2024-2526450  T-CROSS  6UA1   CWL  PCEQS709  2049732   ROD
# 979321  2024-2526450  T-CROSS  6UA1   CWL  PCEQS709  2049732   ROD
#
#                                                     FALHA                 DATA
# 1707    Mecanismo de regulagem do volante Acionamento ...  24-01-2023 22:52:19
# 1754                                Console central Risco  24-01-2023 23:09:05
# 1847    Mecanismo de regulagem do volante Acionamento ...  25-01-2023 06:16:31
# 2230                      Revestimento coluna A Ruído (-)  25-01-2023 07:40:02
# 2231                             Tampa traseira Ruído (-)  25-01-2023 07:40:18
# ...                                                   ...                  ...
# 977650  Mecanismo de regulagem do volante Ruído de aci...  14-06-2024 13:17:09
# 977750  Retrovisor - Espelho retrovisor interno Ruído (-)  14-06-2024 13:38:52
# 979175      Alavanca de mudança de marcha (02) Função NOK  14-06-2024 18:46:41
# 979317                           Tampa traseira Ruído (-)  14-06-2024 20:29:11
# 979321      Revestimento porta  (42/52/64C/64D) Ruído (-)  14-06-2024 20:29:35
#
# [7577 rows x 9 columns]

# %%
# Visualizar quantos tipos de falhas diferentes há na base de dados
total_falhas = df_falhas_limpa['FALHA'].unique()
len(total_falhas)
# Out:
# 580

# %%
# Visualizar qual tipo de falha é a mais comum 
df_falhas_limpa['FALHA'].value_counts()
# Out:
# FALHA
# Tampa traseira Ruído (-)                                               1317
# Revestimento coluna A Ruído (-)                                         620
# Batente porta dianteira Ruído (-)                                       487
# Console central Ruído (-)                                               377
# Side valance (Carcaça do banco diant.) Interfere                        329
#                                                                        ...
# Chapas defletoras de calor no assoalho Ruído de peça solta                1
# Instrumento combinado Montagem NOK                                        1
# Elem. deslizante estrutura assento (Trilho guia) Deslocado (Ajuste)       1
# Cobertura do motor Montagem NOK                                           1
# Teto/teto moldado (cheio) Ruído de peça solta                             1
# Name: count, Length: 580, dtype: int64

# %%
# Dropando colunas que não serao utilizadas
df_falhas_limpa = df_falhas_limpa.drop(['MODELO','DATA'], axis='columns')
df_falhas_limpa
# Out:
#                  KNR   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...   ...   ...       ...      ...   ...
# 977650  2024-2526472  2R2R   DHS  PCEQS709  2034913   ROD
# 977750  2024-2446009  0QA1   DHS  PCEQS709  4013395   ROD
# 979175  2024-2526492  K2K2   DHS  PCEQS709  4024346   ROD
# 979317  2024-2526450  6UA1   CWL  PCEQS709  2049732   ROD
# 979321  2024-2526450  6UA1   CWL  PCEQS709  2049732   ROD
#
#                                                     FALHA
# 1707    Mecanismo de regulagem do volante Acionamento ...
# 1754                                Console central Risco
# 1847    Mecanismo de regulagem do volante Acionamento ...
# 2230                      Revestimento coluna A Ruído (-)
# 2231                             Tampa traseira Ruído (-)
# ...                                                   ...
# 977650  Mecanismo de regulagem do volante Ruído de aci...
# 977750  Retrovisor - Espelho retrovisor interno Ruído (-)
# 979175      Alavanca de mudança de marcha (02) Função NOK
# 979317                           Tampa traseira Ruído (-)
# 979321      Revestimento porta  (42/52/64C/64D) Ruído (-)
#
# [7577 rows x 7 columns]

# %%
# Coloca todas as letras em maiúscula para que possa pegar todos os dados repetidos
df_falhas_limpa['FALHA'] = df_falhas_limpa['FALHA'].str.upper()
df_falhas_limpa
# Out:
#                  KNR   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...   ...   ...       ...      ...   ...
# 977650  2024-2526472  2R2R   DHS  PCEQS709  2034913   ROD
# 977750  2024-2446009  0QA1   DHS  PCEQS709  4013395   ROD
# 979175  2024-2526492  K2K2   DHS  PCEQS709  4024346   ROD
# 979317  2024-2526450  6UA1   CWL  PCEQS709  2049732   ROD
# 979321  2024-2526450  6UA1   CWL  PCEQS709  2049732   ROD
#
#                                                     FALHA
# 1707    MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 1754                                CONSOLE CENTRAL RISCO
# 1847    MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 2230                      REVESTIMENTO COLUNA A RUÍDO (-)
# 2231                             TAMPA TRASEIRA RUÍDO (-)
# ...                                                   ...
# 977650  MECANISMO DE REGULAGEM DO VOLANTE RUÍDO DE ACI...
# 977750  RETROVISOR - ESPELHO RETROVISOR INTERNO RUÍDO (-)
# 979175      ALAVANCA DE MUDANÇA DE MARCHA (02) FUNÇÃO NOK
# 979317                           TAMPA TRASEIRA RUÍDO (-)
# 979321      REVESTIMENTO PORTA  (42/52/64C/64D) RUÍDO (-)
#
# [7577 rows x 7 columns]

# %%
# Visualizando o total de falhas diferentes presentes na tabela

total_falhas = df_falhas_limpa['FALHA'].unique()
len(total_falhas)
# Out:
# 580

# %%
# Verificando o tamanho da base de dados
df_falhas_limpa.shape
# Out:
# (7577, 7)

# %%
# Colunas que não serão utilizadas no modelo
lixo = {"COR", "MOTOR","ESTACAO", "USUARIO", "HALLE" }
df_falhas_limpa_drop = df_falhas_limpa.drop(columns=lixo)

# %%
# Criando uma nova tabela a partir da df_falhas_limpa
df_falhas_limpa_true = df_falhas_limpa_drop
df_falhas_limpa_true
# Out:
#                  KNR                                              FALHA
# 1707    2023-0436112  MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 1754    2023-0436064                              CONSOLE CENTRAL RISCO
# 1847    2023-0436473  MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 2230    2023-0436117                    REVESTIMENTO COLUNA A RUÍDO (-)
# 2231    2023-0436117                           TAMPA TRASEIRA RUÍDO (-)
# ...              ...                                                ...
# 977650  2024-2526472  MECANISMO DE REGULAGEM DO VOLANTE RUÍDO DE ACI...
# 977750  2024-2446009  RETROVISOR - ESPELHO RETROVISOR INTERNO RUÍDO (-)
# 979175  2024-2526492      ALAVANCA DE MUDANÇA DE MARCHA (02) FUNÇÃO NOK
# 979317  2024-2526450                           TAMPA TRASEIRA RUÍDO (-)
# 979321  2024-2526450      REVESTIMENTO PORTA  (42/52/64C/64D) RUÍDO (-)
#
# [7577 rows x 2 columns]

# %%
df_falhas_limpa_true['FALHA'] = 1

# %%
# Preenchendo os resultados nulos por 0
df_falhas_limpa_true_filled = df_falhas_limpa_true.fillna(0)

# Transforma os valores não nulos para 1
df_falhas_limpa_true_filled[df_falhas_limpa_true_filled != 0] = 1

# %%
# Eliminando KNRs repetidos
df_falhas_limpa_true_unicos = df_falhas_limpa_true.drop_duplicates(subset='KNR')
df_falhas_limpa_true_unicos
# Out:
#                  KNR  FALHA
# 1707    2023-0436112      1
# 1754    2023-0436064      1
# 1847    2023-0436473      1
# 2230    2023-0436117      1
# 2283    2023-0436069      1
# ...              ...    ...
# 977578  2024-2446106      1
# 977650  2024-2526472      1
# 977750  2024-2446009      1
# 979175  2024-2526492      1
# 979317  2024-2526450      1
#
# [6586 rows x 2 columns]

# %%
# Salvando a tabela tratada
df_falhas_limpa_true_unicos.to_csv('../tabelas finais/FALHAS_TRUE.csv', index=False)
