# %% [markdown]
# # 1. Exploração e limpeza das bases de dados

# %%
# importacao das dependencias
import pandas as pd
import numpy as np

# %% [markdown]
# ## Converte **_xlsx_** para **_csv_**

# %%
# Ler a planilha
df = pd.read_excel('../tabelas originais/FALHAS_PREDICT')

# Converter para .csv
csv_file = '..tabelas originais/FALHAS_PREDICT.csv'
df.to_csv(csv_file, index=False)

# %% [markdown]
# ## Base de dados "FALHAS_PREDICT""

# %%
# Leitura da base de dados falhas
df_falhas = pd.read_csv('FALHAS_PREDICT.csv')
df_falhas
# Out:
#         Unnamed: 0           KNR   MODELO   COR MOTOR   ESTACAO  USUARIO  \
# 0                2  2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521
# 1                3  2023-1326197  T-CROSS  0Q0Q   DHS  PCEQS100  2043521
# 2                4  2023-4130482  AUDI Q3  2Y2Y   DSN  PCEQS999  2054701
# 3                5  2023-4130482  AUDI Q3  2Y2Y   DSN  PCEQS999  2054701
# 4                6  2023-4130664  AUDI Q3  6Y6Y   DSN  PCEQS805  7000240
# ...            ...           ...      ...   ...   ...       ...      ...
# 663814      663816  2024-1336453  T-CROSS  K2K2   DHS  HCEQS506  2051427
# 663815      663817  2024-1336485  T-CROSS  0Q0Q   DHS  HCEQS506  2044862
# 663816      663818  2024-1346004  T-CROSS  A1A1   DHS  HCEQS506  2052733
# 663817      663819  2024-1336453  T-CROSS  K2K2   DHS  HCEQS506  2051427
# 663818      663820  2024-1336485  T-CROSS  0Q0Q   DHS  HCEQS506  2044862
#
#        HALLE                                          FALHA  \
# 0        ZP5                 Porta dianteira Folga (Ajuste)
# 1        ZP5                  Porta traseira Folga (Ajuste)
# 2       ESPC                   Lanterna tras (09) Interfere
# 3       ESPC  Emblema / logo - Adesivos em geral Solto(a) ¨
# 4       ZP82                  Painel instrumentos Ruído (-)
# ...      ...                                            ...
# 663814  ZP7           TAMPA TRASEIRA 05. SUJEIRA NA PINTURA
# 663815  ZP7                       PORTA TRASEIRA 03. CAVACO
# 663816  ZP7                    RACK DO TETO FELTRO APARENTE
# 663817  ZP7                      TAMPA TRASEIRA 07. FERVIDO
# 663818  ZP7                PAINEL LATERAL PREP. PINTURA NOK
#
#                               DATA
# 0       2023-01-09 22:24:44.272000
# 1       2023-01-09 22:25:02.960000
# 2       2023-01-10 09:18:25.238000
# 3       2023-01-10 09:18:40.728000
# 4       2023-01-10 11:17:56.489000
# ...                            ...
# 663814  2024-03-27 14:52:39.400000
# 663815  2024-03-27 14:53:03.187000
# 663816  2024-03-27 14:53:25.992000
# 663817  2024-03-27 14:53:29.873000
# 663818  2024-03-27 14:54:05.634000
#
# [663819 rows x 10 columns]

# %%
# Dropando a coluna Unnamed
df_falhas.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# Visualização da forma da base de dados para saber com que estamos lidando
df_falhas.shape
# Out:
# (663819, 9)

# %%
# Para saber que os dados que estão dispostos para trabalharmos
df_falhas.columns
# Out:
# Index(['KNR', 'MODELO', 'COR', 'MOTOR', 'ESTACAO', 'USUARIO', 'HALLE', 'FALHA',
#        'DATA'],
#       dtype='object')

# %%
# Saber os tipos de cada coluna para ter noção do que vamos lidar 
df_falhas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663819 entries, 0 to 663818
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   KNR      663819 non-null  object
#  1   MODELO   663819 non-null  object
#  2   COR      663819 non-null  object
#  3   MOTOR    663819 non-null  object
#  4   ESTACAO  663816 non-null  object
#  5   USUARIO  663816 non-null  object
#  6   HALLE    662762 non-null  object
#  7   FALHA    663809 non-null  object
#  8   DATA     663819 non-null  object
# dtypes: object(9)
# memory usage: 45.6+ MB

# %%
# Ter informações de quais dados são nulos e sua quantidade para saber quatos irão ser descartados
df_falhas.isna().sum()
# Out:
# KNR           0
# MODELO        0
# COR           0
# MOTOR         0
# ESTACAO       3
# USUARIO       3
# HALLE      1057
# FALHA        10
# DATA          0
# dtype: int64

# %%
# Visualizar quais modelos estão dispostos na base de dados 
df_falhas['MODELO'].value_counts()
# Out:
# MODELO
# T-CROSS       657163
# T-CROSS PA      3439
# AUDI Q3         3217
# Name: count, dtype: int64

# %%
# Limpar a base de dados para excluir todos os campos que estão vazios
df_falhas_limpa = df_falhas.dropna()
df_falhas_limpa.shape
# Out:
# (662752, 9)

# %%
# Ter mais informações sobre como os dados estão organizados em seus tipos
df_falhas_limpa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 662752 entries, 0 to 663818
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   KNR      662752 non-null  object
#  1   MODELO   662752 non-null  object
#  2   COR      662752 non-null  object
#  3   MOTOR    662752 non-null  object
#  4   ESTACAO  662752 non-null  object
#  5   USUARIO  662752 non-null  object
#  6   HALLE    662752 non-null  object
#  7   FALHA    662752 non-null  object
#  8   DATA     662752 non-null  object
# dtypes: object(9)
# memory usage: 50.6+ MB

# %%
# Pegar somente os dados do tipo T-Cross, pois será o foco da análise
df_falhas_limpa1 = df_falhas_limpa[df_falhas_limpa['MODELO'] == 'T-CROSS']
df_falhas_limpa1['MODELO'].unique()
# Out:
# array(['T-CROSS'], dtype=object)

# %%
# Pegar somente os dados do tipo ROD, pois será o foco da análise
df_falhas_limpa = df_falhas_limpa1[df_falhas_limpa1['HALLE'] == 'ROD']

df_falhas_limpa
# Out:
#                  KNR   MODELO   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  T-CROSS  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  T-CROSS  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  T-CROSS  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  T-CROSS  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  T-CROSS  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...      ...   ...   ...       ...      ...   ...
# 651964  2024-1246414  T-CROSS  0Q0Q   DRP  PCEQS709  2049732   ROD
# 651984  2024-1256233  T-CROSS  A1A1   DHS  PCEQS709  2057190   ROD
# 652131  2024-1316099  T-CROSS  5T5T   CWL  PCEQS709  4003084   ROD
# 652168  2024-1316101  T-CROSS  5T5T   CWL  PCEQS709  4003084   ROD
# 652407  2024-1236086  T-CROSS  0Q0Q   DHS  PCEQS709  2049732   ROD
#
#                                                     FALHA  \
# 1707    Mecanismo de regulagem do volante Acionamento ...
# 1754                                Console central Risco
# 1847    Mecanismo de regulagem do volante Acionamento ...
# 2230                      Revestimento coluna A Ruído (-)
# 2231                             Tampa traseira Ruído (-)
# ...                                                   ...
# 651964                           Tampa traseira Ruído (-)
# 651984                          Console central Ruído (-)
# 652131                           Tampa traseira Ruído (-)
# 652168                Teto/teto moldado (cheio) Ruído (-)
# 652407                    Revestimento coluna A Ruído (-)
#
#                               DATA
# 1707    2023-01-24 22:52:19.236000
# 1754    2023-01-24 23:09:05.460000
# 1847    2023-01-25 06:16:31.603000
# 2230    2023-01-25 07:40:02.215000
# 2231    2023-01-25 07:40:18.659000
# ...                            ...
# 651964  2024-03-22 18:39:58.187000
# 651984  2024-03-22 18:43:13.140000
# 652131  2024-03-22 20:10:22.099000
# 652168  2024-03-22 20:18:34.517000
# 652407  2024-03-22 20:55:19.844000
#
# [5606 rows x 9 columns]

# %%
# Visualizar quantos tipos de falhas diferentes há na base de dados
total_falhas = df_falhas_limpa['FALHA'].unique()
len(total_falhas)
# Out:
# 505

# %%
# Visualizar qual tipo de falha é a mais comum 
df_falhas_limpa['FALHA'].value_counts()
# Out:
# FALHA
# Tampa traseira Ruído (-)                            971
# Revestimento coluna A Ruído (-)                     491
# Side valance (Carcaça do banco diant.) Interfere    329
# Batente porta dianteira Ruído (-)                   300
# Console central Ruído (-)                           276
#                                                    ...
# Iluminação central interna (09) Ruído de chapa        1
# Braço do limpador Dianteiro Danificado (a) ¨          1
# Caixa de água Danificado (a) ¨                        1
# Caixa transmissão - respiro Falta ¨                   1
# Braço do limpador Dianteiro Lixamento NOK             1
# Name: count, Length: 505, dtype: int64

# %%
# Dropando colunas que não serao utilizadas
df_falhas_limpa = df_falhas_limpa.drop(['MODELO','DATA'], axis='columns')
df_falhas_limpa
# Out:
#                  KNR   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...   ...   ...       ...      ...   ...
# 651964  2024-1246414  0Q0Q   DRP  PCEQS709  2049732   ROD
# 651984  2024-1256233  A1A1   DHS  PCEQS709  2057190   ROD
# 652131  2024-1316099  5T5T   CWL  PCEQS709  4003084   ROD
# 652168  2024-1316101  5T5T   CWL  PCEQS709  4003084   ROD
# 652407  2024-1236086  0Q0Q   DHS  PCEQS709  2049732   ROD
#
#                                                     FALHA
# 1707    Mecanismo de regulagem do volante Acionamento ...
# 1754                                Console central Risco
# 1847    Mecanismo de regulagem do volante Acionamento ...
# 2230                      Revestimento coluna A Ruído (-)
# 2231                             Tampa traseira Ruído (-)
# ...                                                   ...
# 651964                           Tampa traseira Ruído (-)
# 651984                          Console central Ruído (-)
# 652131                           Tampa traseira Ruído (-)
# 652168                Teto/teto moldado (cheio) Ruído (-)
# 652407                    Revestimento coluna A Ruído (-)
#
# [5606 rows x 7 columns]

# %%
# Coloca todas as letras em maiúscula para que possa pegar todos os dados repetidos
df_falhas_limpa['FALHA'] = df_falhas_limpa['FALHA'].str.upper()
df_falhas_limpa
# Out:
#                  KNR   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...   ...   ...       ...      ...   ...
# 651964  2024-1246414  0Q0Q   DRP  PCEQS709  2049732   ROD
# 651984  2024-1256233  A1A1   DHS  PCEQS709  2057190   ROD
# 652131  2024-1316099  5T5T   CWL  PCEQS709  4003084   ROD
# 652168  2024-1316101  5T5T   CWL  PCEQS709  4003084   ROD
# 652407  2024-1236086  0Q0Q   DHS  PCEQS709  2049732   ROD
#
#                                                     FALHA
# 1707    MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 1754                                CONSOLE CENTRAL RISCO
# 1847    MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 2230                      REVESTIMENTO COLUNA A RUÍDO (-)
# 2231                             TAMPA TRASEIRA RUÍDO (-)
# ...                                                   ...
# 651964                           TAMPA TRASEIRA RUÍDO (-)
# 651984                          CONSOLE CENTRAL RUÍDO (-)
# 652131                           TAMPA TRASEIRA RUÍDO (-)
# 652168                TETO/TETO MOLDADO (CHEIO) RUÍDO (-)
# 652407                    REVESTIMENTO COLUNA A RUÍDO (-)
#
# [5606 rows x 7 columns]

# %%
# Visualizando o total de falhas diferentes presentes na tabela

total_falhas = df_falhas_limpa['FALHA'].unique()
len(total_falhas)
# Out:
# 505

# %%
# Elimina os dados repetidos

df_falhas_limpa = df_falhas_limpa.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df_falhas_limpa = df_falhas_limpa.astype(str)
df_falhas_limpa = df_falhas_limpa.drop_duplicates()

# %%
# Verificando o tamanho da base de dados
df_falhas_limpa.shape
# Out:
# (5589, 7)

# %%
# Colunas que não serão utilizadas no modelo
lixo = {"COR", "MOTOR","ESTACAO", "USUARIO", "HALLE" }
df_falhas_limpa.drop(columns=lixo)
# Out:
#                  KNR                                              FALHA
# 1707    2023-0436112  MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 1754    2023-0436064                              CONSOLE CENTRAL RISCO
# 1847    2023-0436473  MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 2230    2023-0436117                    REVESTIMENTO COLUNA A RUÍDO (-)
# 2231    2023-0436117                           TAMPA TRASEIRA RUÍDO (-)
# ...              ...                                                ...
# 651964  2024-1246414                           TAMPA TRASEIRA RUÍDO (-)
# 651984  2024-1256233                          CONSOLE CENTRAL RUÍDO (-)
# 652131  2024-1316099                           TAMPA TRASEIRA RUÍDO (-)
# 652168  2024-1316101                TETO/TETO MOLDADO (CHEIO) RUÍDO (-)
# 652407  2024-1236086                    REVESTIMENTO COLUNA A RUÍDO (-)
#
# [5589 rows x 2 columns]

# %%
# Criando uma nova tabalea a partir da df_falhas_limpa
df_falhas_limpa_true = df_falhas_limpa
df_falhas_limpa_true
# Out:
#                  KNR   COR MOTOR   ESTACAO  USUARIO HALLE  \
# 1707    2023-0436112  8E8E   CWL  PCEQS709  2078090   ROD
# 1754    2023-0436064  0Q0Q   CWL  PCEQS709  2078090   ROD
# 1847    2023-0436473  A1A1   DHS  PCEQS709  2058677   ROD
# 2230    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# 2231    2023-0436117  8E8E   DHS  PCEQS709  2049783   ROD
# ...              ...   ...   ...       ...      ...   ...
# 651964  2024-1246414  0Q0Q   DRP  PCEQS709  2049732   ROD
# 651984  2024-1256233  A1A1   DHS  PCEQS709  2057190   ROD
# 652131  2024-1316099  5T5T   CWL  PCEQS709  4003084   ROD
# 652168  2024-1316101  5T5T   CWL  PCEQS709  4003084   ROD
# 652407  2024-1236086  0Q0Q   DHS  PCEQS709  2049732   ROD
#
#                                                     FALHA
# 1707    MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 1754                                CONSOLE CENTRAL RISCO
# 1847    MECANISMO DE REGULAGEM DO VOLANTE ACIONAMENTO ...
# 2230                      REVESTIMENTO COLUNA A RUÍDO (-)
# 2231                             TAMPA TRASEIRA RUÍDO (-)
# ...                                                   ...
# 651964                           TAMPA TRASEIRA RUÍDO (-)
# 651984                          CONSOLE CENTRAL RUÍDO (-)
# 652131                           TAMPA TRASEIRA RUÍDO (-)
# 652168                TETO/TETO MOLDADO (CHEIO) RUÍDO (-)
# 652407                    REVESTIMENTO COLUNA A RUÍDO (-)
#
# [5589 rows x 7 columns]

# %%
# Preenchendo os resultados nulos por 0
df_falhas_limpa_true_filled = df_falhas_limpa_true.fillna(0)

# Transforma os valores não nulos para 1
df_falhas_limpa_true_filled[df_falhas_limpa_true_filled != 0] = 1

# %%
# Apando colunas que não serão utilizada no modelo
apagar = {'COR', 'MOTOR', 'ESTACAO', 'USUARIO', 'HALLE'}
df_falhas_limpa_true = df_falhas_limpa_true.drop(columns=apagar)

# %%
# Atribuindo para coluna FALHA todos os valores como 1 para indicar que há uma falha 
df_falhas_limpa_true['FALHA'] = 1

# %%
# Eliminando KNRs repetidos
df_falhas_limpa_true_unicos = df_falhas_limpa_true.drop_duplicates(subset='KNR')
df_falhas_limpa_true_unicos
# Out:
#                  KNR  FALHA
# 1707    2023-0436112      1
# 1754    2023-0436064      1
# 1847    2023-0436473      1
# 2230    2023-0436117      1
# 2283    2023-0436069      1
# ...              ...    ...
# 651960  2024-1246414      1
# 651984  2024-1256233      1
# 652131  2024-1316099      1
# 652168  2024-1316101      1
# 652407  2024-1236086      1
#
# [4863 rows x 2 columns]

# %%
# Salvando a tabela tratada
df_falhas_limpa_true_unicos.to_csv('tabelas finais/FALHAS_PREDICT_TRUE.csv', index=False)
